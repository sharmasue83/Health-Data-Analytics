# %%
#import dependencies
import pandas as pd
import os
import matplotlib
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
bcg_data = pd.read_excel('immunization_data.xlsx', sheet_name='BCG')
bcg_data.head()
# Out:
#                    unicef_region iso3      country vaccine  2017  2016  2015  \
# 0                     South Asia  AFG  Afghanistan     BCG  74.0  74.0  74.0
# 1  Eastern Europe & Central Asia  ALB      Albania     BCG  99.0  99.0  99.0
# 2     Middle East & North Africa  DZA      Algeria     BCG  99.0  99.0  99.0
# 3      Eastern & Southern Africa  AGO       Angola     BCG  83.0  49.0  69.0
# 4      Latin America & Caribbean  ARG    Argentina     BCG  95.0  92.0  96.0
#
#    2014  2013  2012  ...  1989  1988  1987  1986  1985  1984  1983  1982  \
# 0  74.0  72.0  78.0  ...  38.0  40.0  27.0  18.0  17.0  11.0  10.0  10.0
# 1  99.0  99.0  96.0  ...  94.0  92.0  92.0  92.0  92.0  90.0  90.0  92.0
# 2  99.0  99.0  99.0  ...  96.0  96.0  93.0  88.0  86.0   NaN   NaN   NaN
# 3  72.0  71.0  74.0  ...  47.0  32.0  29.0  32.0  28.0  28.0  25.0   NaN
# 4  99.0  99.0  99.0  ...  92.0  91.0  94.0  99.0  90.0  78.0  70.0  77.0
#
#    1981  1980
# 0   NaN   NaN
# 1  93.0  93.0
# 2   NaN   NaN
# ...

# %%
Immunization =bcg_data.columns.values[4:]
Immunization
# Out:
# array(['2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010',
#        '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002',
#        '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994',
#        '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986',
#        '1985', '1984', '1983', '1982', '1981', '1980'], dtype=object)

# %%
country_list = bcg_data['country']

# %%
new_df = {'Years':list(bcg_data.columns.values[4:]),
         '%Immunization': bcg_data.loc[bcg_data['country']== 'Argentina']}

# %%
Years=list(bcg_data.columns.values[4:])
Years
#Immunization= bcg_data.loc[bcg_data['country']== 'Argentina']
#Immunization
# Out:
# ['2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '1999',
#  '1998',
#  '1997',
#  '1996',
#  '1995',
#  '1994',
#  '1993',
#  '1992',
#  '1991',
#  '1990',
#  '1989',
#  '1988',
#  '1987',
#  '1986',
#  '1985',
#  '1984',
#  '1983',
#  '1982',
#  '1981',
#  '1980']

# %%
data = []
for year in Years:
    for country in country_list:
    
        bcg_tmp_df = bcg_data[(bcg_data['country'] == country)]
        tmp_bcg = bcg_tmp_df[str(year)]
        data.append({'Year' : int(year), 'BCG': list(tmp_bcg.values)[0]})
        
            #data.append({'GNP' :0, 'BCG': list(tmp_bcg.values)[0]})
data
# Out:
# [{'Year': 2017, 'BCG': 74.0},
#  {'Year': 2017, 'BCG': 99.0},
#  {'Year': 2017, 'BCG': 99.0},
#  {'Year': 2017, 'BCG': 83.0},
#  {'Year': 2017, 'BCG': 95.0},
#  {'Year': 2017, 'BCG': 99.0},
#  {'Year': 2017, 'BCG': nan},
#  {'Year': 2017, 'BCG': 97.0},
#  {'Year': 2017, 'BCG': 99.0},
#  {'Year': 2017, 'BCG': 98.0},
#  {'Year': 2017, 'BCG': 90.0},
#  {'Year': 2017, 'BCG': 96.0},
#  {'Year': 2017, 'BCG': 99.0},
#  {'Year': 2017, 'BCG': 93.0},
#  {'Year': 2017, 'BCG': 97.0},
#  {'Year': 2017, 'BCG': 98.0},
#  {'Year': 2017, 'BCG': 90.0},
#  {'Year': 2017, 'BCG': 99.0},
#  {'Year': 2017, 'BCG': 96.0},
#  {'Year': 2017, 'BCG': 98.0},
#  {'Year': 2017, 'BCG': 92.0},
#  {'Year': 2017, 'BCG': 98.0},
#  {'Year': 2017, 'BCG': 99.0},
#  {'Year': 2017, 'BCG': 91.0},
#  {'Year': 2017, 'BCG': 74.0},
#  {'Year': 2017, 'BCG': 59.0},
#  {'Year': 2017, 'BCG': 96.0},
#  {'Year': 2017, 'BCG': 99.0},
#  {'Year': 2017, 'BCG': 91.0},
#  {'Year': 2017, 'BCG': 94.0},
#  {'Year': 2017, 'BCG': 76.0},
# ...

# %%
bcg_argentina =pd.DataFrame(data)
bcg_argentina.dropna(inplace=True)

# %%
import numpy as np
from sklearn import preprocessing, svm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# considering year as label as we need to predict the year
X = np.array(bcg_argentina.drop(['Year'], 1))
y = np.array(bcg_argentina['Year'])

# %%
# Preprocessing scales the feature set
# 

X = preprocessing.scale(X)
y = np.array(bcg_argentina['Year'])

# %%
#Takes 2 arrays, gives 4 variabes... test size is 20 % of train... 
# train data is selected based built-in algorithm
#allows for re-training... if data become bigger, change parameters and re-train...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Support VEctor regression

clf = svm.SVR()
clf.fit(X_train, y_train)

confidence = clf.score(X_test, y_test)
print(confidence)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.13195483007872577

# %%
clf = LinearRegression()
clf = LinearRegression(n_jobs=-1)

for k in ['linear','poly','rbf','sigmoid']:
    clf = svm.SVR(kernel=k)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    print(k,confidence)
# Out:
# linear 0.19299083666452332
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# poly 0.0911277675634854
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# rbf 0.19534353948458938
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-c51e2d02cf50> in <module>
# ----> 1 X_lately = X[-forecast_out:]
#       2 forecast_set = clf.predict(X_lately)
#
# NameError: name 'forecast_out' is not defined
